# %% [markdown]
# # Github Project
# ## Group 1
#
# Using SFE.py to finite element model data from images analysed in skimmage
# Need to look up:
# - edge detection
# - image processing
# - image filtering

# %% [markdown]
# ## First, a little tutorial:

# %%
import numpy as np
print("I like ", np.pi)
# Out:
# I like  3.141592653589793

# %%
from scipy import misc
import matplotlib.pyplot as plt

face = misc.face()
plt.imshow(face)
plt.show()

# %%
# Import skimage to read image and matplotlib to plot image from data
from skimage import io
from matplotlib import pyplot as plt
# Importskimage scaling and sizing tools
from skimage.transform import rescale, resize, downscale_local_mean

# Define image from filepath
img = io.imread("~/Desktop/git_project/pic1.png", as_gray=True) # replace image filepath

# Rescale the image
rescaled_img = rescale(img, 1.0/4.0, anti_aliasing=True)

# Varying the image data
newimg = img

# Showing the image
print(newimg) # Print the image as data
plt.imshow(newimg) # Plot image data, recreating image.
# Out:
# [[0.         0.         0.         ... 0.         0.         0.        ]
#  [1.         0.99215686 0.98039216 ... 0.45098039 0.49019608 0.61176471]
#  [1.         0.98431373 0.98039216 ... 0.49411765 0.46666667 0.56862745]
#  ...
#  [0.95294118 0.90588235 0.94117647 ... 0.88235294 0.89019608 0.88627451]
#  [0.90588235 0.89803922 0.92156863 ... 0.90196078 0.89019608 0.88235294]
#  [0.90588235 0.89803922 0.90588235 ... 0.89019608 0.87843137 0.87843137]]
